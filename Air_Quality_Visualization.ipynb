# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - Nama: Imam Agus Faisal
# - Email: imamagusfaisal120@gmail.com
# - Id Dicoding: imamaf

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Stasiun mana yang memiliki kadar rata-rata Karbon Monoksida (CO) tertinggi dan terendah?
# - Urutkan stasiun dengan kadar rata-rata Particulate Matter yang berdiameter 10 mikron atau kurang (PM10) dari terendah ke tertinggi?
# - Bagaimana kadar PM2.5 pada Stasiun Wanliu pada 12 bulan terakhir?

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data
# **Mengambil data dari dataset yang telah dipersiapkan**

# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Unzip dataset dari drive**

# %%
# !unzip "drive/MyDrive/Dataset/Air-quality-dataset.zip"
# Out:
# Archive:  drive/MyDrive/Dataset/Air-quality-dataset.zip
#    creating: PRSA_Data_20130301-20170228/
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv
#   inflating: PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv
# ...

# %% [markdown]
# **Memuat setiap tabel pada dataset**

# %%
aotizhongxin_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv')
changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dingling_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv')
dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
dongsi_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv')
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
guanyuan_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv')
guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
gucheng_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv')
gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
huairou_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv')
huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
nongzhanguan_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
shunyi_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv')
shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
tiantan_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv')
tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
wanliu_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv')
wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
wanshouxigong_df = pd.read_csv('/content/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv')
wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data
# **Melihat informasi, Memeriksa missing value, Memeriksa duplikasi, dan Memeriksa parameter statistik pada setiap tabel**

# %%
print('\n', aotizhongxin_df.info())
print('\nMissing value aotizhongxin:\n', aotizhongxin_df.isnull().sum())
print('\nJumlah duplikasi aotizhongxin:\n', aotizhongxin_df.duplicated().sum())
print('\n\nParameter statistik aotizhongxin:\n', aotizhongxin_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', changping_df.info())
print('\nMissing value changping:\n', changping_df.isnull().sum())
print('\nJumlah duplikasi changping:\n', changping_df.duplicated().sum())
print('\n\nParameter statistik changping:\n', changping_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', dingling_df.info())
print('\nMissing value dingling:\n', dingling_df.isnull().sum())
print('\nJumlah duplikasi dingling:\n', dingling_df.duplicated().sum())
print('\n\nParameter statistik dingling:\n', dingling_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', dongsi_df.info())
print('\nMissing value dongsi:\n', dongsi_df.isnull().sum())
print('\nJumlah duplikasi dongsi:\n', dongsi_df.duplicated().sum())
print('\n\nParameter statistik dongsi:\n', dongsi_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', guanyuan_df.info())
print('\nMissing value guanyuan:\n', guanyuan_df.isnull().sum())
print('\nJumlah duplikasi guanyuan:\n', guanyuan_df.duplicated().sum())
print('\n\nParameter statistik guanyuan:\n', guanyuan_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', gucheng_df.info())
print('\nMissing value gucheng:\n', gucheng_df.isnull().sum())
print('\nJumlah duplikasi gucheng:\n', gucheng_df.duplicated().sum())
print('\n\nParameter statistik gucheng:\n', gucheng_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', huairou_df.info())
print('\nMissing value huairou:\n', huairou_df.isnull().sum())
print('\nJumlah duplikasi huairou:\n', huairou_df.duplicated().sum())
print('\n\nParameter statistik huairou:\n', huairou_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', nongzhanguan_df.info())
print('\nMissing value nongzhanguan:\n', nongzhanguan_df.isnull().sum())
print('\nJumlah duplikasi nongzhanguan:\n', nongzhanguan_df.duplicated().sum())
print('\n\nParameter statistik nongzhanguan:\n', nongzhanguan_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', shunyi_df.info())
print('\nMissing value shunyi:\n', shunyi_df.isnull().sum())
print('\nJumlah duplikasi shunyi:\n', shunyi_df.duplicated().sum())
print('\n\nParameter statistik shunyi:\n', shunyi_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', tiantan_df.info())
print('\nMissing value tiantan:\n', tiantan_df.isnull().sum())
print('\nJumlah duplikasi tiantan:\n', tiantan_df.duplicated().sum())
print('\n\nParameter statistik tiantan:\n', tiantan_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', wanliu_df.info())
print('\nMissing value wanliu:\n', wanliu_df.isnull().sum())
print('\nJumlah duplikasi wanliu:\n', wanliu_df.duplicated().sum())
print('\n\nParameter statistik wanliu:\n', wanliu_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %%
print('\n', wanshouxigong_df.info())
print('\nMissing value wanshouxigong:\n', wanshouxigong_df.isnull().sum())
print('\nJumlah duplikasi wanshouxigong:\n', wanshouxigong_df.duplicated().sum())
print('\n\nParameter statistik wanshouxigong:\n', wanshouxigong_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
#
# ...

# %% [markdown]
# **Rangkuman Hasil Analisis Tahap Assesing Data pada Setiap Tabel:**
# *   Terdapat missing value pada beberapa kolom disetiap tabel
# *   Terdapat kesalahan tipe data pada penanggalan
# *   Tidak terdapat adanya duplikasi
# *   Tidak terdapat innacurate value

# %% [markdown]
# ### Cleaning Data
# **Inisialisasi dataframe untuk interasi**

# %%
dataframes = {
    "aotizhongxin": aotizhongxin_df,
    "changping": changping_df,
    "dingling": dingling_df,
    "dongsi": dongsi_df,
    "guanyuan": guanyuan_df,
    "gucheng": gucheng_df,
    "huairou": huairou_df,
    "nongzhanguan": nongzhanguan_df,
    "shunyi": shunyi_df,
    "tiantan": tiantan_df,
    "wanliu": wanliu_df,
    "wanshouxigong": wanshouxigong_df
}

# %% [markdown]
# **Untuk membersihkan data missing value berupa string, gunakan metode imputation, yaitu mengganti nilai null dengan nilai yang dominan.**

# %% [markdown]
# Simpan top values dari kolom wd ke dalam list

# %%
top_wd = []
for location, df in dataframes.items():
  print(location, " : ", df['wd'].value_counts().nlargest(n=1).index[0])
  top_wd.append(df['wd'].value_counts().nlargest(n=1).index[0])
# Out:
# aotizhongxin  :  NE
# changping  :  NNW
# dingling  :  NNW
# dongsi  :  ENE
# guanyuan  :  NE
# gucheng  :  N
# huairou  :  NW
# nongzhanguan  :  ENE
# shunyi  :  NNE
# tiantan  :  ENE
# wanliu  :  NE
# wanshouxigong  :  NE

# %% [markdown]
# Ganti missing value dengan top value

# %%
for location, df in dataframes.items():
  df['wd'].fillna(top_wd[list(dataframes.keys()).index(location)], inplace=True)

# %% [markdown]
# **Untuk membersihkan data berupa missing value, gunakan metode yang tepat, yaitu interpolation polynomial karena data yang diolah merupakan data timeseries.**

# %%
for location, df in dataframes.items():
  df.interpolate(method='polynomial', order=1, inplace=True)

# %% [markdown]
# **Mengatasi kesalahan tipe data datetime**

# %%
for location, df in dataframes.items():
  df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
  df.set_index('datetime', inplace=True)
  df.drop(['year', 'month', 'day', 'hour'], axis=1, inplace=True)

# %% [markdown]
# **Menghapus Kolom yang tidak digunakan**

# %%
drop_list=['No', 'SO2', 'NO2', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']
for location, df in dataframes.items():
  df.drop(drop_list, axis=1, inplace=True)

# %% [markdown]
# **Mengecek hasil cleaning data**

# %%
for location, df in dataframes.items():
  print("\n\n", location, "\n",df.isna().sum())
# Out:
#  aotizhongxin
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  changping
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  dingling
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  dongsi
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  guanyuan
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  gucheng
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  huairou
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  nongzhanguan
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  shunyi
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  tiantan
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# dtype: int64
#
#
#  wanliu
#  PM2.5      0
# PM10       0
# CO         0
# station    0
# ...

# %%
for location, df in dataframes.items():
  print(location, ": ",df.duplicated().sum())
# Out:
# aotizhongxin :  9083
# changping :  9238
# dingling :  11322
# dongsi :  8323
# guanyuan :  8077
# gucheng :  6651
# huairou :  11085
# nongzhanguan :  8496
# shunyi :  9881
# tiantan :  8771
# wanliu :  7669
# wanshouxigong :  7949

# %%
for location, df in dataframes.items():
  df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    35064 non-null  float64
#  1   PM10     35064 non-null  float64
#  2   CO       35064 non-null  float64
#  3   station  35064 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    35064 non-null  float64
#  1   PM10     35064 non-null  float64
#  2   CO       35064 non-null  float64
#  3   station  35064 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore tabel pada setiap dataset

# %%
aotizhongxin_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO       station
# count   35064.000000  35064.000000  35064.000000         35064
# unique           NaN           NaN           NaN             1
# top              NaN           NaN           NaN  Aotizhongxin
# freq             NaN           NaN           NaN         35064
# mean       82.540623    110.210033   1264.692405           NaN
# std        81.956401     95.262531   1239.411826           NaN
# min         3.000000      2.000000    100.000000           NaN
# 25%        22.000000     38.000000    500.000000           NaN
# 50%        58.000000     87.000000    900.000000           NaN
# 75%       114.000000    154.000000   1500.000000           NaN
# max       898.000000    984.000000  10000.000000           NaN

# %%
changping_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO    station
# count   35064.000000  35064.000000  35064.000000      35064
# unique           NaN           NaN           NaN          1
# top              NaN           NaN           NaN  Changping
# freq             NaN           NaN           NaN      35064
# mean       70.986438     94.788575   1156.990246        NaN
# std        72.397726     83.928515   1122.612745        NaN
# min         2.000000      2.000000    100.000000        NaN
# 25%        18.000000     34.000000    500.000000        NaN
# 50%        46.000000     72.000000    800.000000        NaN
# 75%       100.000000    131.000000   1400.000000        NaN
# max       882.000000    999.000000  10000.000000        NaN

# %%
dingling_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO   station
# count   35064.000000  35064.000000  35064.000000     35064
# unique           NaN           NaN           NaN         1
# top              NaN           NaN           NaN  Dingling
# freq             NaN           NaN           NaN     35064
# mean       66.845557     84.113713    925.111838       NaN
# std        73.445093     80.242081    894.687311       NaN
# min         3.000000      2.000000    100.000000       NaN
# 25%        14.000000     26.000000    300.000000       NaN
# 50%        41.000000     60.000000    600.000000       NaN
# 75%        94.000000    118.000000   1200.000000       NaN
# max       881.000000    905.000000  10000.000000       NaN

# %%
dongsi_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO station
# count   35064.000000  35064.000000  35064.000000   35064
# unique           NaN           NaN           NaN       1
# top              NaN           NaN           NaN  Dongsi
# freq             NaN           NaN           NaN   35064
# mean       86.144243    110.347617   1331.913045     NaN
# std        86.260246     98.239918   1169.035307     NaN
# min         3.000000      2.000000    100.000000     NaN
# 25%        23.000000     38.000000    600.000000     NaN
# 50%        61.000000     86.000000   1000.000000     NaN
# 75%       119.000000    150.000000   1700.000000     NaN
# max       737.000000    955.000000  10000.000000     NaN

# %%
guanyuan_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO   station
# count   35064.000000  35064.000000  35064.000000     35064
# unique           NaN           NaN           NaN         1
# top              NaN           NaN           NaN  Guanyuan
# freq             NaN           NaN           NaN     35064
# mean       82.897522    109.372349   1258.327045       NaN
# std        81.070279     92.340966   1151.647467       NaN
# min         2.000000      2.000000    100.000000       NaN
# 25%        23.000000     40.000000    500.000000       NaN
# 50%        59.000000     89.000000    900.000000       NaN
# 75%       114.000000    149.000000   1500.000000       NaN
# max       680.000000    999.000000  10000.000000       NaN

# %%
gucheng_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO  station
# count   35064.000000  35064.000000  35064.000000    35064
# unique           NaN           NaN           NaN        1
# top              NaN           NaN           NaN  Gucheng
# freq             NaN           NaN           NaN    35064
# mean       84.074802    119.261567   1338.100060      NaN
# std        82.994634     97.533240   1214.044983      NaN
# min         2.000000      2.000000    100.000000      NaN
# 25%        24.000000     45.000000    600.000000      NaN
# 50%        60.000000    100.000000    985.714286      NaN
# 75%       116.000000    167.000000   1680.652174      NaN
# max       770.000000    994.000000  10000.000000      NaN

# %%
huairou_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO  station
# count   35064.000000  35064.000000  35064.000000    35064
# unique           NaN           NaN           NaN        1
# top              NaN           NaN           NaN  Huairou
# freq             NaN           NaN           NaN    35064
# mean       69.501747     92.422670   1019.671871      NaN
# std        70.990900     84.792119    890.539429      NaN
# min         2.000000      2.000000    100.000000      NaN
# 25%        17.000000     29.000000    400.000000      NaN
# 50%        47.000000     69.000000    800.000000      NaN
# 75%        98.000000    131.000000   1300.000000      NaN
# max       762.000000    993.000000  10000.000000      NaN

# %%
nongzhanguan_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO       station
# count   35064.000000  35064.000000  35064.000000         35064
# unique           NaN           NaN           NaN             1
# top              NaN           NaN           NaN  Nongzhanguan
# freq             NaN           NaN           NaN         35064
# mean       85.079472    109.384022   1327.767611           NaN
# std        86.692516     96.088407   1257.098704           NaN
# min         2.000000      2.000000    100.000000           NaN
# 25%        22.000000     38.000000    500.000000           NaN
# 50%        59.000000     85.000000    900.000000           NaN
# 75%       116.000000    149.000000   1600.000000           NaN
# max       844.000000    995.000000  10000.000000           NaN

# %%
shunyi_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO station
# count   35064.000000  35064.000000  35064.000000   35064
# unique           NaN           NaN           NaN       1
# top              NaN           NaN           NaN  Shunyi
# freq             NaN           NaN           NaN   35064
# mean       79.437962     99.271936   1197.904660     NaN
# std        81.500282     90.579040   1162.920922     NaN
# min         2.000000      2.000000    100.000000     NaN
# 25%        19.000000     31.000000    400.000000     NaN
# 50%        55.000000     77.000000    900.000000     NaN
# 75%       111.000000    139.000000   1500.000000     NaN
# max       941.000000    999.000000  10000.000000     NaN

# %%
tiantan_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO  station
# count   35064.000000  35064.000000  35064.000000    35064
# unique           NaN           NaN           NaN        1
# top              NaN           NaN           NaN  Tiantan
# freq             NaN           NaN           NaN    35064
# mean       82.033097    106.537076   1305.333262      NaN
# std        80.895489     90.277762   1179.450046      NaN
# min         3.000000      2.000000    100.000000      NaN
# 25%        22.000000     41.000000    518.125000      NaN
# 50%        58.000000     85.000000    900.000000      NaN
# 75%       113.000000    144.000000   1600.000000      NaN
# max       821.000000    988.000000  10000.000000      NaN

# %%
wanliu_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO station
# count   35064.000000  35064.000000  35064.000000   35064
# unique           NaN           NaN           NaN       1
# top              NaN           NaN           NaN  Wanliu
# freq             NaN           NaN           NaN   35064
# mean       83.467612    110.707858   1328.761180     NaN
# std        82.125058     93.539605   1263.218948     NaN
# min         2.000000      2.000000    100.000000     NaN
# 25%        23.000000     40.000000    600.000000     NaN
# 50%        59.000000     88.000000    900.000000     NaN
# 75%       116.000000    153.000000   1600.000000     NaN
# max       957.000000    951.000000  10000.000000     NaN

# %%
wanshouxigong_df.describe(include='all')
# Out:
#                PM2.5          PM10            CO        station
# count   35064.000000  35064.000000  35064.000000          35064
# unique           NaN           NaN           NaN              1
# top              NaN           NaN           NaN  Wanshouxigong
# freq             NaN           NaN           NaN          35064
# mean       85.067548    112.505795   1373.618569            NaN
# std        85.999698     98.132120   1228.161525            NaN
# min         3.000000      2.000000    100.000000            NaN
# 25%        23.000000     39.000000    600.000000            NaN
# 50%        60.000000     91.000000   1000.000000            NaN
# 75%       116.000000    154.000000   1700.000000            NaN
# max       999.000000    961.000000   9800.000000            NaN

# %% [markdown]
# **Merge data mengenai kandungan kualitas udara pada tiap stasiun ke dalam 1 dataframe**

# %%
air_quality_df = aotizhongxin_df

# %%
skip_first = True
for location, df in dataframes.items():
  if skip_first:
        skip_first = False
        continue  # Skip the first location (aotizhongxin_df)
  air_quality_df = pd.merge(
      left=air_quality_df,
      right=df,
      how="left",
      left_on="datetime",
      right_on="datetime",
      suffixes=("", f"_{location}")
      )

# %%
column_mapping = {
    'PM2.5': 'PM2.5_aotizhongxin',
    'PM10': 'PM10_aotizhongxin',
    'CO': 'CO_aotizhongxin',
    'station': 'station_aotizhongxin'
}
air_quality_df = air_quality_df.rename(columns=column_mapping)

# %% [markdown]
# **Hapus kolom 'stasiun_...' karena nama stasiun sudah diwakilkan dengan akhiran nama masing-masing kolom**

# %%
station_columns_to_drop = [col for col in air_quality_df.columns if col.startswith('station_')]

air_quality_df = air_quality_df.drop(columns=station_columns_to_drop)

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5_aotizhongxin   35064 non-null  float64
#  1   PM10_aotizhongxin    35064 non-null  float64
#  2   CO_aotizhongxin      35064 non-null  float64
#  3   PM2.5_changping      35064 non-null  float64
#  4   PM10_changping       35064 non-null  float64
#  5   CO_changping         35064 non-null  float64
#  6   PM2.5_dingling       35064 non-null  float64
#  7   PM10_dingling        35064 non-null  float64
#  8   CO_dingling          35064 non-null  float64
#  9   PM2.5_dongsi         35064 non-null  float64
#  10  PM10_dongsi          35064 non-null  float64
#  11  CO_dongsi            35064 non-null  float64
#  12  PM2.5_guanyuan       35064 non-null  float64
#  13  PM10_guanyuan        35064 non-null  float64
# ...

# %% [markdown]
# **Membuat dataframe baru yang berisi Data Timeseries Air Quality di Stasiun Wanliu**

# %%
wanliu_timeseries_df = wanliu_df.copy()

# %%
wanliu_timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    35064 non-null  float64
#  1   PM10     35064 non-null  float64
#  2   CO       35064 non-null  float64
#  3   station  35064 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 1.3+ MB

# %%
print(wanliu_timeseries_df)
# Out:
#                      PM2.5  PM10     CO station
# datetime
# 2013-03-01 00:00:00    8.0   8.0  400.0  Wanliu
# 2013-03-01 01:00:00    9.0   9.0  400.0  Wanliu
# 2013-03-01 02:00:00    3.0   6.0  400.0  Wanliu
# 2013-03-01 03:00:00   11.0  30.0  350.0  Wanliu
# 2013-03-01 04:00:00    3.0  13.0  300.0  Wanliu
# ...                    ...   ...    ...     ...
# 2017-02-28 19:00:00   11.0  27.0  300.0  Wanliu
# 2017-02-28 20:00:00   15.0  43.0  500.0  Wanliu
# 2017-02-28 21:00:00   13.0  35.0  500.0  Wanliu
# 2017-02-28 22:00:00   12.0  31.0  500.0  Wanliu
# 2017-02-28 23:00:00    7.0  25.0  700.0  Wanliu
#
# [35064 rows x 4 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Stasiun mana yang memiliki kadar rata-rata Karbon Monoksida (CO) tertinggi dan terendah?

# %% [markdown]
# **Mengekstrak data CO Mean dari air_quality_df**

# %%
CO_columns = [col for col in air_quality_df.columns if col.startswith('CO_')]
mean_CO_df=air_quality_df[CO_columns].copy()
mean_CO_df=mean_CO_df.describe().loc['mean']
mean_CO_df=mean_CO_df.reset_index()
mean_CO_df=mean_CO_df.rename(columns={'index': 'station', 'mean': 'CO mean'})
mean_CO_df['station'] = mean_CO_df['station'].str.replace('CO_', '', regex=False)

# %%
mean_CO_df.head()
# Out:
#         station      CO mean
# 0  aotizhongxin  1264.692405
# 1     changping  1156.990246
# 2      dingling   925.111838
# 3        dongsi  1331.913045
# 4      guanyuan  1258.327045

# %% [markdown]
# **Mengurutkan data secara descending**

# %%
sorted_mean_CO_df = mean_CO_df.sort_values(by="CO mean", ascending=False)
print(sorted_mean_CO_df.to_string(index=False))
# Out:
#       station     CO mean
# wanshouxigong 1373.618569
#       gucheng 1338.100060
#        dongsi 1331.913045
#        wanliu 1328.761180
#  nongzhanguan 1327.767611
#       tiantan 1305.333262
#  aotizhongxin 1264.692405
#      guanyuan 1258.327045
#        shunyi 1197.904660
#     changping 1156.990246
#       huairou 1019.671871
#      dingling  925.111838

# %% [markdown]
# **Menampilkan data dalam bentuk Bar Chart**

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors1 = ["r", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
colors2 = ["#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "g"]

sns.barplot(x="CO mean", y="station", data=sorted_mean_CO_df.head(6), palette=colors1, ax=ax[0])
ax[0].set_ylabel("Station", fontsize=13)
ax[0].set_xlabel("Average Carbon Monoxide (CO)", fontsize=13)
ax[0].set_title("Highest Average Carbon Monoxide (CO)", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=13)
ax[0].tick_params(axis ='x', labelsize=13)

sns.barplot(x="CO mean", y="station", data=sorted_mean_CO_df.tail(6), palette=colors2, ax=ax[1])
ax[1].set_ylabel("Station", fontsize=13)
ax[1].set_xlabel("Average Carbon Monoxide (CO)", fontsize=13)
ax[1].set_title("Lowest Average Carbon Monoxide (CO)", fontsize=15)
ax[1].tick_params(axis ='y', labelsize=13)
ax[1].tick_params(axis ='x', labelsize=13)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()

plt.suptitle("Highest and Lowest Average Carbon Monoxide (CO) at the Station", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Urutkan stasiun dengan kadar rata-rata Particulate Matter yang berdiameter 10 mikron atau kurang (PM10) dari terendah ke tertinggi?

# %% [markdown]
# **Mengekstrak data PM10 Mean dari air_quality_df**

# %%
PM10_columns = [col for col in air_quality_df.columns if col.startswith('PM10_')]
mean_PM10_df=air_quality_df[PM10_columns].copy()
mean_PM10_df=mean_PM10_df.describe().loc['mean']
mean_PM10_df=mean_PM10_df.reset_index()
mean_PM10_df=mean_PM10_df.rename(columns={'index': 'station', 'mean': 'PM10 mean'})
mean_PM10_df['station'] = mean_PM10_df['station'].str.replace('PM10_', '', regex=False)

# %%
mean_PM10_df.head()
# Out:
#         station   PM10 mean
# 0  aotizhongxin  110.210033
# 1     changping   94.788575
# 2      dingling   84.113713
# 3        dongsi  110.347617
# 4      guanyuan  109.372349

# %% [markdown]
# **Mengurutkan data secara ascending**

# %%
sorted_mean_PM10_df = mean_PM10_df.sort_values(by="PM10 mean", ascending=True)
print(sorted_mean_PM10_df.to_string(index=False))
# Out:
#       station  PM10 mean
#      dingling  84.113713
#       huairou  92.422670
#     changping  94.788575
#        shunyi  99.271936
#       tiantan 106.537076
#      guanyuan 109.372349
#  nongzhanguan 109.384022
#  aotizhongxin 110.210033
#        dongsi 110.347617
#        wanliu 110.707858
# wanshouxigong 112.505795
#       gucheng 119.261567

# %% [markdown]
# **Menampilkan data dalam bentuk Bar Chart**

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 7))

colors = ["#068DA9"]

sns.barplot(x="PM10 mean", y="station", data=sorted_mean_PM10_df, palette=colors)
ax.set_ylabel("Station", fontsize=13)
ax.set_xlabel("Average PM 10", fontsize=13)
ax.set_title("Order of Average PM 10 Per Station (Low to High)", fontsize=15)
ax.tick_params(axis ='y', labelsize=11)
ax.tick_params(axis ='x', labelsize=11)

plt.show()

# %% [markdown]
# ### Pertanyaan 3: Bagaimana kadar PM2.5 pada Stasiun Wanliu pada 12 bulan terakhir?

# %%
wanliu_monthly_df = wanliu_timeseries_df.reset_index()

# %%
wanliu_monthly_df = wanliu_monthly_df.resample(rule='M', on='datetime').agg({
    "PM2.5": "mean",
})
wanliu_monthly_df.index = wanliu_monthly_df.index.strftime('%Y %B')
wanliu_monthly_df = wanliu_monthly_df.reset_index()

# %%
wanliu_monthly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  48 non-null     object
#  1   PM2.5     48 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 896.0+ bytes

# %%
wanliu_monthly_df.head()
# Out:
#      datetime       PM2.5
# 0  2013 March  110.272849
# 1  2013 April   66.541667
# 2    2013 May   92.978495
# 3   2013 June  119.980556
# 4   2013 July   75.714382

# %%
# Create a line chart
last_1_year = wanliu_monthly_df.tail(12)
plt.figure(figsize=(12, 5))
plt.plot(
    last_1_year['datetime'],
    last_1_year['PM2.5'],
    marker='o',
    linestyle='-',
    color='r')
plt.title('Average Monthly PM 2.5 at Wanliu Station (Last 12 Months)')
plt.xticks(fontsize=10, rotation=45)
plt.xlabel('Date')
plt.yticks(fontsize=10)
plt.ylabel('PM 2.5 level')
plt.grid(True, linestyle='--', linewidth=0.5, which='both', color='gray')

# Show the line chart
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Stasiun mana yang memiliki kadar rata-rata Karbon Monoksida (CO) tertinggi dan terendah?
# > Berdasarkan hasil dari Data Visualization menggunakan Bar Chart, dapat diambil kesimpulan bahwa stasiun dengan kadar rata-rata Karbon Monoksida (CO) **tertinggi** terdapat pada **Stasiun Wanshouxigong** dan stasiun dengan kadar rata-rata Karbon Monoksida (CO) **terendah** terdapat pada **Stasiun Dingling**
# - Urutkan stasiun dengan kadar rata-rata Particulate Matter yang berdiameter 10 mikron atau kurang (PM10) dari terendah ke tertinggi?
# > Berdasarkan hasil dari Data Visualization menggunakan Bar Chart, dapat diambil kesimpulan bahwa urutan stasiun dengan kadar rata-rata Particulate Matter yang berdiameter 10 mikron atau kurang (PM10) dari **terendah ke tertinggi** yaitu:
#   1.   Dingling
#   2.   Huairou
#   3.   Changping
#   4.   Shunyi
#   5.   Tiantan
#   6.   Guanyuan
#   7.   Nongzhanguan
#   8.   Aotizhongxin
#   9.   Dongsi
#   10.   Wanliu
#   11.   Wanshouxigong
#   12.   Gucheng
#
# - Bagaimana kandungan PM2.5 pada Stasiun Wanliu pada 12 bulan terakhir?
# > Berdasarkan hasil dari Data Visualization menggunakan Line Chart, dapat diambil kesimpulan bahwa data 12 bulan terakhir cenderung fluktuatif. Kenaikan kadar PM2.5 secara signifikan terjadi pada rentang bulan Oktober 2016 - Januari 2017 dan puncaknya pada bulan Januari 2017. Namun, kadar PM2.5 kembali menurun tajam pada bulan Maret 2017.

# %% [markdown]
# ## Export Data
# Data yang akan diexport yaitu:
# - Data Air Quality
# - Data Timeseries PM2.5 Stasiun Wanliu
#
# Data timeseries tidak akan digabung, karena berbeda format data (Timeseries).

# %% [markdown]
# **Reset index untuk dijadikan kolom datetime di Streamlit**

# %%
air_quality_df = air_quality_df.reset_index()
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             35064 non-null  datetime64[ns]
#  1   PM2.5_aotizhongxin   35064 non-null  float64
#  2   PM10_aotizhongxin    35064 non-null  float64
#  3   CO_aotizhongxin      35064 non-null  float64
#  4   PM2.5_changping      35064 non-null  float64
#  5   PM10_changping       35064 non-null  float64
#  6   CO_changping         35064 non-null  float64
#  7   PM2.5_dingling       35064 non-null  float64
#  8   PM10_dingling        35064 non-null  float64
#  9   CO_dingling          35064 non-null  float64
#  10  PM2.5_dongsi         35064 non-null  float64
#  11  PM10_dongsi          35064 non-null  float64
#  12  CO_dongsi            35064 non-null  float64
#  13  PM2.5_guanyuan       35064 non-null  float64
# ...

# %%
wanliu_timeseries_df = wanliu_timeseries_df.reset_index()
wanliu_timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  datetime64[ns]
#  1   PM2.5     35064 non-null  float64
#  2   PM10      35064 non-null  float64
#  3   CO        35064 non-null  float64
#  4   station   35064 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# **Simpan semua data yang digunakan untuk Streamlit**

# %%
air_quality_df.to_csv("air_quality_df.csv", index=False)
wanliu_timeseries_df.to_csv("wanliu_timeseries_df.csv", index=False)
